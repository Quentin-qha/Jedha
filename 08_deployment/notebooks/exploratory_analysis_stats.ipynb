# %%
import pandas as pd 
import numpy as np
import plotly.express as px

# %%
data = pd.read_excel('../data/get_around_delay_analysis.xlsx')
data.head()
# Out:
#    rental_id  car_id checkin_type     state  delay_at_checkout_in_minutes  \
# 0     505000  363965       mobile  canceled                           NaN
# 1     507750  269550       mobile     ended                         -81.0
# 2     508131  359049      connect     ended                          70.0
# 3     508865  299063      connect  canceled                           NaN
# 4     511440  313932       mobile     ended                           NaN
#
#    previous_ended_rental_id  time_delta_with_previous_rental_in_minutes
# 0                       NaN                                         NaN
# 1                       NaN                                         NaN
# 2                       NaN                                         NaN
# 3                       NaN                                         NaN
# 4                       NaN                                         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21310 entries, 0 to 21309
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rental_id                                   21310 non-null  int64
#  1   car_id                                      21310 non-null  int64
#  2   checkin_type                                21310 non-null  object
#  3   state                                       21310 non-null  object
#  4   delay_at_checkout_in_minutes                16346 non-null  float64
#  5   previous_ended_rental_id                    1841 non-null   float64
#  6   time_delta_with_previous_rental_in_minutes  1841 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
data.shape
# Out:
# (21310, 7)

# %%
data.isnull().sum()/len(data)*100
# Out:
# rental_id                                      0.000000
# car_id                                         0.000000
# checkin_type                                   0.000000
# state                                          0.000000
# delay_at_checkout_in_minutes                  23.294228
# previous_ended_rental_id                      91.360863
# time_delta_with_previous_rental_in_minutes    91.360863
# dtype: float64

# %%
data.describe()
# Out:
#            rental_id         car_id  delay_at_checkout_in_minutes  \
# count   21310.000000   21310.000000                  16346.000000
# mean   549712.880338  350030.603426                     59.701517
# std     13863.446964   58206.249765                   1002.561635
# min    504806.000000  159250.000000                 -22433.000000
# 25%    540613.250000  317639.000000                    -36.000000
# 50%    550350.000000  368717.000000                      9.000000
# 75%    560468.500000  394928.000000                     67.000000
# max    576401.000000  417675.000000                  71084.000000
#
#        previous_ended_rental_id  time_delta_with_previous_rental_in_minutes
# count               1841.000000                                 1841.000000
# mean              550127.411733                                  279.288430
# std                13184.023111                                  254.594486
# ...

# %%
data['car_id'].value_counts()
# Out:
# car_id
# 334190    33
# 392479    29
# 241021    29
# 342699    27
# 300505    24
#           ..
# 372160     1
# 297623     1
# 403246     1
# 267750     1
# 408598     1
# Name: count, Length: 8143, dtype: int64

# %%
data['rental_id'].value_counts()
# Out:
# rental_id
# 505000    1
# 558908    1
# 558830    1
# 558767    1
# 558746    1
#          ..
# 568143    1
# 568065    1
# 568035    1
# 567994    1
# 575056    1
# Name: count, Length: 21310, dtype: int64

# %%
data['delay_at_checkout_in_minutes'].mean()
# Out:
# 59.70151719075003

# %%
data['checkin_type'].value_counts()
# Out:
# checkin_type
# mobile     17003
# connect     4307
# Name: count, dtype: int64

# %%
data['state'].value_counts()
# Out:
# state
# ended       18045
# canceled     3265
# Name: count, dtype: int64

# %%
data_clean = data[
    (data['delay_at_checkout_in_minutes'] >= -2880) &
    (data['delay_at_checkout_in_minutes'] <= 2880)
]

len(data_clean)/len(data)
# Out:
# 0.7632097606757391

# %%
data_clean[data_clean["time_delta_with_previous_rental_in_minutes"].notna()]
# Out:
#        rental_id  car_id checkin_type  state  delay_at_checkout_in_minutes  \
# 6         511639  370585      connect  ended                         -15.0
# 19        519491  312389       mobile  ended                          58.0
# 40        528808  181625      connect  ended                         -76.0
# 64        533670  320824      connect  ended                          -6.0
# 74        534827  404169       mobile  ended                          -7.0
# ...          ...     ...          ...    ...                           ...
# 21249     571823  353425      connect  ended                        -276.0
# 21253     573274  298117      connect  ended                          -7.0
# 21266     567741  294059       mobile  ended                         111.0
# 21275     568523  297973       mobile  ended                          12.0
# 21286     569717  377312       mobile  ended                         230.0
#
# ...
