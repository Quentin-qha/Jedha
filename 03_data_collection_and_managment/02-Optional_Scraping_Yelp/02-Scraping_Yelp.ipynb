# %% [markdown]
# # Scraping Yelp
#
# The aim of this exercise is to allow a user to make an automatic search on <a href="https://www.yelp.fr/" target="_blank">Yelp</a> and store the results in a `.json` file. You will be guided through the different steps: making a form request with search keywords, parsing the search results, crawling all the result pages and storing the results into a file.
#
# ⚠ **As scrapy is not made to launch several crawler processes in the same script, you will have to restart your notebook's kernel before completing each question!**

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.6.1-py2.py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 10.6 MB/s
# Collecting w3lib>=1.17.0
#   Using cached w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting cssselect>=0.9.1
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting parsel>=1.5.0
#   Using cached parsel-1.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: cryptography>=2.0 in /opt/conda/lib/python3.9/site-packages (from scrapy) (36.0.1)
# Collecting service-identity>=16.0.0
#   Using cached service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Collecting zope.interface>=4.1.3
#   Using cached zope.interface-5.4.0-cp39-cp39-manylinux2010_x86_64.whl (255 kB)
# Collecting tldextract
#   Downloading tldextract-3.2.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 5.2 MB/s
# Collecting lxml>=3.5.0
#   Using cached lxml-4.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
# Collecting PyDispatcher>=2.0.5
#   Using cached PyDispatcher-2.0.5-py3-none-any.whl
# Collecting itemadapter>=0.1.0
#   Using cached itemadapter-0.4.0-py3-none-any.whl (10 kB)
# Collecting itemloaders>=1.0.1
#   Using cached itemloaders-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in /opt/conda/lib/python3.9/site-packages (from scrapy) (22.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from scrapy) (59.8.0)
# Collecting queuelib>=1.4.2
#   Using cached queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting protego>=0.1.15
#   Using cached Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting Twisted>=17.9.0
#   Downloading Twisted-22.2.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 30.2 MB/s
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.9/site-packages (from cryptography>=2.0->scrapy) (1.15.0)
# Collecting jmespath>=0.9.5
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=19.1.0 in /opt/conda/lib/python3.9/site-packages (from service-identity>=16.0.0->scrapy) (21.4.0)
# Collecting pyasn1-modules
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting pyasn1
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting hyperlink>=17.1.1
#   Using cached hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
# Collecting constantly>=15.1
#   Using cached constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting incremental>=21.3.0
#   Using cached incremental-21.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/conda/lib/python3.9/site-packages (from Twisted>=17.9.0->scrapy) (4.0.1)
# Collecting Automat>=0.8.0
#   Using cached Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Collecting filelock>=3.0.8
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: idna in /opt/conda/lib/python3.9/site-packages (from tldextract->scrapy) (3.3)
# Requirement already satisfied: requests>=2.1.0 in /opt/conda/lib/python3.9/site-packages (from tldextract->scrapy) (2.27.1)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.0->scrapy) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.10)
# Installing collected packages: w3lib, pyasn1, lxml, cssselect, zope.interface, requests-file, pyasn1-modules, parsel, jmespath, itemadapter, incremental, hyperlink, filelock, constantly, Automat, Twisted, tldextract, service-identity, queuelib, PyDispatcher, protego, itemloaders, scrapy
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 Twisted-22.2.0 constantly-15.1.0 cssselect-1.1.0 filelock-3.6.0 hyperlink-21.0.0 incremental-21.3.0 itemadapter-0.4.0 itemloaders-1.0.4 jmespath-1.0.0 lxml-4.8.0 parsel-1.6.0 protego-0.2.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.6.1 service-identity-21.1.0 tldextract-3.2.0 w3lib-1.22.0 zope.interface-5.4.0

# %% [markdown]
# 1. Create a class `YelpSpider(scrapy.Spider)` with `start_urls = ['https://www.yelp.fr/']`. In this class, define a `parse(self, response)` method that automatically fills Yelp's homepage form with : "restaurant japonais" as search keywords and "Paris" as search location. Then, define another method `after_search(self, response)` that parses the first page of results, and yields the name and url of each search result. Finally, declare a `CrawlerProcess` that will store the results in a file named `"restaurant_japonais-paris.json"`.

# %%
# !python yelp1.py
# Out:
# 2025-05-11 18:17:04 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2025-05-11 18:17:04 [scrapy.utils.log] INFO: Versions: lxml 5.2.1.0, libxml2 2.13.1, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:28:27) [Clang 14.0.6 ], pyOpenSSL 24.2.1 (OpenSSL 3.0.15 3 Sep 2024), cryptography 43.0.0, Platform macOS-10.16-x86_64-i386-64bit
# 2025-05-11 18:17:04 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-05-11 18:17:04 [py.warnings] WARNING: /opt/anaconda3/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-05-11 18:17:04 [scrapy.extensions.telnet] INFO: Telnet Password: d91f9d165e25e01e
# 2025-05-11 18:17:04 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-05-11 18:17:04 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2025-05-11 18:17:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-05-11 18:17:05 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-05-11 18:17:05 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-05-11 18:17:05 [scrapy.core.engine] INFO: Spider opened
# 2025-05-11 18:17:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-05-11 18:17:05 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [yelp] INFO: Dernière page atteinte.
# 2025-05-11 18:17:49 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-05-11 18:17:49 [scrapy.extensions.feedexport] INFO: Stored json feed (240 items) in: results/restaurant_japonais-paris.json
# 2025-05-11 18:17:49 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 10801,
#  'downloader/request_count': 24,
#  'downloader/request_method_count/GET': 24,
#  'downloader/response_bytes': 1651811,
#  'downloader/response_count': 24,
#  'downloader/response_status_count/200': 24,
#  'dupefilter/filtered': 207,
#  'elapsed_time_seconds': 44.529328,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 5, 11, 16, 17, 49, 566159, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 13987935,
#  'httpcompression/response_count': 24,
#  'item_scraped_count': 240,
#  'log_count/INFO': 21,
#  'log_count/WARNING': 1,
#  'memusage/max': 61587456,
#  'memusage/startup': 61587456,
#  'request_depth_max': 23,
#  'response_received_count': 24,
#  'scheduler/dequeued': 24,
#  'scheduler/dequeued/memory': 24,
#  'scheduler/enqueued': 24,
#  'scheduler/enqueued/memory': 24,
#  'start_time': datetime.datetime(2025, 5, 11, 16, 17, 5, 36831, tzinfo=datetime.timezone.utc)}
# 2025-05-11 18:17:49 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# 2. Once you've managed to get the first page's results in `restaurant_japonais-paris.json`, complete the `after_search(self,response)` method to crawl the different result pages, such that all the search results will be stored in the file `"restaurant_japonais-paris.json"`. Restart your notebook's kernel, execute the new `CrawlerProcess` and check that all the search results (and not only the first page) are now stored in the file.

# %%
# !python yelp2.py
# Out:
#   Cell In[35], line 1
#     python yelp_test.py
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Congrats, you've just made the proof of concept of making an automated search on Yelp with Scrapy! Now, let's improve the script such that it will allow the user to make any search at any location 😎
#
# 3. Use python's `input()` function to ask the user which keywords and location he would like to use, and save them into two variables: `search_keywords` and `search_location`. Then, change the `parse(self, response)` method such that it fills Yelp's form with user-defined keywords and location. Finally, change the `CrawlerProcess` such that it stores the results in a file named with the following format : `search_keywords-location.json`.
#
# Try your search engine with different keywords and locations ✌️

# %% [markdown]
# Run the following command in the terminal to be able to interract
# ```shell
# python 02-Optional_scraping_yelp/yelp3.py
# ```

# %% [markdown]
# 4. Create a script that will use the json file you just created to create a list of urls you wish to scrape and then

# %%
import json

with open('results/restaurant_japonais-paris.json', 'r') as f:
    json_result = json.load(f)

json_result
# Out:
# [{'name': 'Big Fernand',
#   'location': 'Bellecour',
#   'rating': '4.0 ',
#   'nb_reviews': '(168 reviews)',
#   'url': '/biz/big-fernand-lyon?osq=burger'},
#  {'name': 'Bënnie Organic',
#   'location': 'Terreaux',
#   'rating': '4.1 ',
#   'nb_reviews': '(50 reviews)',
#   'url': '/biz/b%C3%ABnnie-organic-lyon?osq=burger'},
#  {'name': 'Les Frangins',
#   'location': 'Bellecour',
#   'rating': '4.0 ',
#   'nb_reviews': '(114 reviews)',
#   'url': '/biz/les-frangins-lyon?osq=burger'},
#  {'name': 'Steak ‘n Shake',
#   'location': 'Part-Dieu',
#   'rating': '2.3 ',
#   'nb_reviews': '(4 reviews)',
#   'url': '/biz/steak-n-shake-lyon-3?osq=burger'},
#  {'name': 'Les Tontons Burgers',
#   'location': 'Saint-Georges',
#   'rating': '4.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/les-tontons-burgers-lyon?osq=burger'},
#  {'name': 'The Dog’s Bollocks',
#   'location': 'Croix-Rousse',
#   'rating': '3.8 ',
#   'nb_reviews': '(34 reviews)',
#   'url': '/biz/the-dogs-bollocks-lyon?osq=burger'},
#  {'name': 'Cosy Corner',
#   'location': 'Saint-Jean',
#   'rating': '4.3 ',
#   'nb_reviews': '(43 reviews)',
#   'url': '/biz/cosy-corner-lyon?osq=burger'},
#  {'name': 'Guy & Sons Cordeliers',
#   'location': 'Cordeliers',
#   'rating': '3.7 ',
#   'nb_reviews': '(184 reviews)',
#   'url': '/biz/guy-et-sons-cordeliers-lyon?osq=burger'},
#  {'name': 'King Marcel',
#   'location': 'Part-Dieu',
#   'rating': '3.8 ',
#   'nb_reviews': '(55 reviews)',
#   'url': '/biz/king-marcel-lyon-7?osq=burger'},
#  {'name': 'Franklin’s Steakhouse',
#   'location': 'Ainay',
#   'rating': '4.1 ',
#   'nb_reviews': '(42 reviews)',
#   'url': '/biz/franklins-steakhouse-lyon?osq=burger'},
#  {'name': 'Butcher',
#   'location': 'Cordeliers',
#   'rating': '4.0 ',
#   'nb_reviews': '(140 reviews)',
#   'url': '/biz/butcher-lyon?osq=burger'},
#  {'name': 'The Star Ferry',
#   'location': 'Berges du Rhône',
#   'rating': '3.9 ',
#   'nb_reviews': '(136 reviews)',
#   'url': '/biz/the-star-ferry-lyon?osq=burger'},
#  {'name': 'Johnny’s Kitchen',
#   'location': 'Saint-Georges',
#   'rating': '3.8 ',
#   'nb_reviews': '(98 reviews)',
#   'url': '/biz/johnnys-kitchen-lyon?osq=burger'},
#  {'name': 'Les Burgers de Papa',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '4.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/les-burgers-de-papa-lyon-8?osq=burger'},
#  {'name': 'Kemptown Food Truck',
#   'location': 'Croix-Rousse',
#   'rating': '5.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/kemptown-food-truck-lyon?osq=burger'},
#  {'name': 'Le Zinc à Burger',
#   'location': 'Bellecour',
#   'rating': '3.3 ',
#   'nb_reviews': '(8 reviews)',
#   'url': '/biz/le-zinc-%C3%A0-burger-lyon?osq=burger'},
#  {'name': 'The New World Smoke',
#   'location': 'Vieux-Lyon',
#   'rating': '4.2 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/the-new-world-smoke-lyon?osq=burger'},
#  {'name': 'Les Burgers de Papa',
#   'location': 'Charpennes',
#   'rating': '3.7 ',
#   'nb_reviews': '(42 reviews)',
#   'url': '/biz/les-burgers-de-papa-villeurbanne?osq=burger'},
#  {'name': 'Burgers & Bagels Lafayette',
#   'location': '6ème arrondissement',
#   'rating': '2.6 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/burgers-et-bagels-lafayette-lyon?osq=burger'},
#  {'name': 'Les Burgers de Papa',
#   'location': 'Gerland',
#   'rating': '3.3 ',
#   'nb_reviews': '(8 reviews)',
#   'url': '/biz/les-burgers-de-papa-lyon-5?osq=burger'},
#  {'name': 'Bintje & Zoet',
#   'location': 'Saint-Jean',
#   'rating': '3.7 ',
#   'nb_reviews': '(47 reviews)',
#   'url': '/biz/bintje-et-zoet-lyon?osq=burger'},
#  {'name': 'Balzamik',
#   'location': '4ème arrondissement',
#   'rating': '4.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/balzamik-caluire-et-cuire?osq=burger'},
#  {'name': 'Chicken Inn',
#   'location': 'Jean Macé',
#   'rating': '4.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/chicken-inn-lyon?osq=burger'},
#  {'name': 'Afrika Burger',
#   'location': 'Perrache',
#   'rating': '5.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/afrika-burger-lyon?osq=burger'},
#  {'name': 'Hank Burger Lyon Opéra',
#   'location': 'Terreaux',
#   'rating': '4.2 ',
#   'nb_reviews': '(9 reviews)',
#   'url': '/biz/hank-burger-lyon-op%C3%A9ra-lyon?osq=burger'},
#  {'name': 'Pinch Burger',
#   'location': '4ème arrondissement',
#   'rating': '3.3 ',
#   'nb_reviews': '(24 reviews)',
#   'url': '/biz/pinch-burger-lyon-2?osq=burger'},
#  {'name': 'Burger’s',
#   'location': '€',
#   'rating': '5.0 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/burgers-saint-priest?osq=burger'},
#  {'name': 'Yabio',
#   'location': 'Terreaux',
#   'rating': '3.9 ',
#   'nb_reviews': '(114 reviews)',
#   'url': '/biz/yabio-lyon?osq=burger'},
#  {'name': 'Les Burgers de Papa',
#   'location': 'La Guillotière',
#   'rating': '2.9 ',
#   'nb_reviews': '(30 reviews)',
#   'url': '/biz/les-burgers-de-papa-lyon-3?osq=burger'},
#  {'name': 'Steak´n Shake',
#   'location': 'Confluence',
#   'rating': '3.7 ',
#   'nb_reviews': '(11 reviews)',
#   'url': '/biz/steak-n-shake-lyon-2?osq=burger'},
#  {'name': 'La Broche',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '3.6 ',
#   'nb_reviews': '(28 reviews)',
#   'url': '/biz/la-broche-lyon?osq=burger'},
#  {'name': 'King Marcel',
#   'location': 'La Guillotière',
#   'rating': '3.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/king-marcel-lyon-9?osq=burger'},
#  {'name': 'Mike',
#   'location': 'Ainay',
#   'rating': '4.7 ',
#   'nb_reviews': '(7 reviews)',
#   'url': '/biz/mike-lyon?osq=burger'},
#  {'name': 'Kaffee Berlin',
#   'location': None,
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/kaffee-berlin-lyon-4?osq=burger'},
#  {'name': 'La Fourmilière',
#   'location': 'La Guillotière',
#   'rating': '4.0 ',
#   'nb_reviews': '(33 reviews)',
#   'url': '/biz/la-fourmili%C3%A8re-lyon?osq=burger'},
#  {'name': 'Lyon’s Gastropub',
#   'location': 'Cordeliers',
#   'rating': '4.1 ',
#   'nb_reviews': '(27 reviews)',
#   'url': '/biz/lyons-gastropub-lyon?osq=burger'},
#  {'name': 'Flanigan’s',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '3.8 ',
#   'nb_reviews': '(69 reviews)',
#   'url': '/biz/flanigans-lyon?osq=burger'},
#  {'name': 'Big Fernand',
#   'location': 'Part-Dieu',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/big-fernand-lyon-3?osq=burger'},
#  {'name': 'La Kolok',
#   'location': 'Jean Macé',
#   'rating': '4.0 ',
#   'nb_reviews': '(25 reviews)',
#   'url': '/biz/la-kolok-lyon?osq=burger'},
#  {'name': 'Les Burgers de Papa',
#   'location': 'Monplaisir',
#   'rating': '3.1 ',
#   'nb_reviews': '(11 reviews)',
#   'url': '/biz/les-burgers-de-papa-lyon-6?osq=burger'},
#  {'name': 'Le Délicieux',
#   'location': 'Caluire',
#   'rating': '4.7 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/le-d%C3%A9licieux-caluire-et-cuire?osq=burger'},
#  {'name': 'Yabio',
#   'location': 'Bellecour',
#   'rating': '3.5 ',
#   'nb_reviews': '(24 reviews)',
#   'url': '/biz/yabio-lyon-2?osq=burger'},
#  {'name': 'L’Origo',
#   'location': 'Croix-Rousse',
#   'rating': '4.2 ',
#   'nb_reviews': '(83 reviews)',
#   'url': '/biz/l-origo-lyon?osq=burger'},
#  {'name': 'Greg et Jerry’s',
#   'location': 'La Guillotière',
#   'rating': '2.7 ',
#   'nb_reviews': '(12 reviews)',
#   'url': '/biz/greg-et-jerrys-lyon?osq=burger'},
#  {'name': 'Frite Alors',
#   'location': 'La Guillotière',
#   'rating': '2.8 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/frite-alors-lyon-2?osq=burger'},
#  {'name': 'Dorodi Pastry',
#   'location': '3ème arrondissement',
#   'rating': '4.6 ',
#   'nb_reviews': '(129 reviews)',
#   'url': '/biz/dorodi-pastry-lyon?osq=burger'},
#  {'name': 'Frite Alors',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '2.9 ',
#   'nb_reviews': '(148 reviews)',
#   'url': '/biz/frite-alors-lyon-3?osq=burger'},
#  {'name': 'Guy & Sons Charpennes',
#   'location': 'Charpennes',
#   'rating': '3.4 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/guy-et-sons-charpennes-lyon?osq=burger'},
#  {'name': 'Hard Rock Cafe',
#   'location': 'Cordeliers',
#   'rating': '3.1 ',
#   'nb_reviews': '(19 reviews)',
#   'url': '/biz/hard-rock-cafe-lyon-3?osq=burger'},
#  {'name': 'Street Art',
#   'location': 'Masséna',
#   'rating': '4.3 ',
#   'nb_reviews': '(25 reviews)',
#   'url': '/biz/street-art-lyon-3?osq=burger'},
#  {'name': 'Chez Gusto',
#   'location': 'Masséna',
#   'rating': '4.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/chez-gusto-lyon?osq=burger'},
#  {'name': 'Délice Croq',
#   'location': 'Vaise',
#   'rating': '4.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/d%C3%A9lice-croq-lyon-2?osq=burger'},
#  {'name': 'Ninkasi',
#   'location': 'Saint-Paul',
#   'rating': '3.6 ',
#   'nb_reviews': '(14 reviews)',
#   'url': '/biz/ninkasi-lyon-12?osq=burger'},
#  {'name': 'Livestation DIY',
#   'location': 'La Guillotière',
#   'rating': '4.2 ',
#   'nb_reviews': '(100 reviews)',
#   'url': '/biz/livestation-diy-lyon?osq=burger'},
#  {'name': 'The Wallace',
#   'location': 'Saint-Paul',
#   'rating': '3.8 ',
#   'nb_reviews': '(124 reviews)',
#   'url': '/biz/the-wallace-lyon?osq=burger'},
#  {'name': 'Diploid',
#   'location': 'Terreaux',
#   'rating': '4.6 ',
#   'nb_reviews': '(39 reviews)',
#   'url': '/biz/diploid-lyon-2?osq=burger'},
#  {'name': 'Eden Rock Café',
#   'location': 'Bellecour',
#   'rating': '3.3 ',
#   'nb_reviews': '(99 reviews)',
#   'url': '/biz/eden-rock-caf%C3%A9-lyon-2?osq=burger'},
#  {'name': 'L’Épicerie',
#   'location': 'Bellecour',
#   'rating': '3.8 ',
#   'nb_reviews': '(317 reviews)',
#   'url': '/biz/l-%C3%A9picerie-lyon-7?osq=burger'},
#  {'name': 'Boston Tavern',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '3.6 ',
#   'nb_reviews': '(41 reviews)',
#   'url': '/biz/boston-tavern-lyon?osq=burger'},
#  {'name': 'La Grillardière',
#   'location': 'Saint-Paul',
#   'rating': '3.5 ',
#   'nb_reviews': '(6 reviews)',
#   'url': '/biz/la-grillardi%C3%A8re-lyon-2?osq=burger'},
#  {'name': 'Queens Town',
#   'location': 'Vaise',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/queens-town-lyon?osq=burger'},
#  {'name': 'The Kelly’s Irish Pub',
#   'location': 'Saint-Jean',
#   'rating': '3.6 ',
#   'nb_reviews': '(42 reviews)',
#   'url': '/biz/the-kellys-irish-pub-lyon-2?osq=burger'},
#  {'name': 'Rem’s',
#   'location': '2ème arrondissement',
#   'rating': '4.2 ',
#   'nb_reviews': '(85 reviews)',
#   'url': '/biz/rems-lyon?osq=burger'},
#  {'name': 'Steak House',
#   'location': 'Charpennes',
#   'rating': '3.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/steak-house-villeurbanne?osq=burger'},
#  {'name': 'Aklé - Le Food Truck',
#   'location': 'La Guillotière',
#   'rating': '4.4 ',
#   'nb_reviews': '(34 reviews)',
#   'url': '/biz/akl%C3%A9-le-food-truck-lyon?osq=burger'},
#  {'name': 'Le Bistrot des Maquignons',
#   'location': 'Garibaldi',
#   'rating': '3.8 ',
#   'nb_reviews': '(118 reviews)',
#   'url': '/biz/le-bistrot-des-maquignons-lyon?osq=burger'},
#  {'name': 'Burger House',
#   'location': '€',
#   'rating': '4.3 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/burger-house-villeurbanne?osq=burger'},
#  {'name': 'Le Café 76',
#   'location': 'Garibaldi',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/le-caf%C3%A9-76-lyon-2?osq=burger'},
#  {'name': 'Bistrot du Boulevard',
#   'location': 'Croix-Rousse',
#   'rating': '4.0 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/bistrot-du-boulevard-lyon?osq=burger'},
#  {'name': 'Brooklyn burgers',
#   'location': 'Vaise',
#   'rating': '4.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/brooklyn-burgers-lyon?osq=burger'},
#  {'name': 'Le Bistrot Canaille',
#   'location': 'Croix-Rousse',
#   'rating': '3.5 ',
#   'nb_reviews': '(6 reviews)',
#   'url': '/biz/le-bistrot-canaille-lyon?osq=burger'},
#  {'name': 'Le Van à Burgers',
#   'location': 'La Guillotière',
#   'rating': '4.2 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/le-van-%C3%A0-burgers-lyon-2?osq=burger'},
#  {'name': 'Les Fromagivores',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '3.8 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/les-fromagivores-lyon?osq=burger'},
#  {'name': 'King Marcel',
#   'location': 'Cordeliers',
#   'rating': '3.6 ',
#   'nb_reviews': '(133 reviews)',
#   'url': '/biz/king-marcel-lyon-8?osq=burger'},
#  {'name': 'Le Court Circuit',
#   'location': 'La Guillotière',
#   'rating': '3.9 ',
#   'nb_reviews': '(50 reviews)',
#   'url': '/biz/le-court-circuit-lyon?osq=burger'},
#  {'name': 'Spok',
#   'location': '3ème arrondissement',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/spok-lyon?osq=burger'},
#  {'name': 'Mastertacos',
#   'location': 'Saxe-Gambetta',
#   'rating': '4.2 ',
#   'nb_reviews': '(58 reviews)',
#   'url': '/biz/mastertacos-lyon-2?osq=burger'},
#  {'name': 'La Mouss’tache',
#   'location': 'Saint-Georges',
#   'rating': '2.8 ',
#   'nb_reviews': '(21 reviews)',
#   'url': '/biz/la-mouss-tache-lyon?osq=burger'},
#  {'name': 'Le Boulanger de Saint-Just',
#   'location': 'Saint-Just',
#   'rating': '4.8 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/le-boulanger-de-saint-just-lyon?osq=burger'},
#  {'name': 'Streat Food',
#   'location': 'Ainay',
#   'rating': '4.7 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/streat-food-lyon?osq=burger'},
#  {'name': 'Hammamet',
#   'location': 'Charpennes',
#   'rating': '1.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/hammamet-villeurbanne?osq=burger'},
#  {'name': 'Ed’s Eat & Drinks',
#   'location': 'Bellecour',
#   'rating': '2.8 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/eds-eat-et-drinks-lyon?osq=burger'},
#  {'name': 'Beefhouse',
#   'location': 'Bellecour',
#   'rating': '3.5 ',
#   'nb_reviews': '(6 reviews)',
#   'url': '/biz/beefhouse-lyon?osq=burger'},
#  {'name': 'Sun 7 Burger',
#   'location': 'Garibaldi',
#   'rating': '3.0 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/sun-7-burger-lyon?osq=burger'},
#  {'name': 'Les Terrasses d’Alex',
#   'location': 'Charpennes',
#   'rating': '4.0 ',
#   'nb_reviews': '(25 reviews)',
#   'url': '/biz/les-terrasses-d-alex-villeurbanne?osq=burger'},
#  {'name': 'My Petite Factory',
#   'location': 'Cordeliers',
#   'rating': '4.0 ',
#   'nb_reviews': '(77 reviews)',
#   'url': '/biz/my-petite-factory-lyon?osq=burger'},
#  {'name': 'Chères Cousines',
#   'location': 'Jean Macé',
#   'rating': '4.0 ',
#   'nb_reviews': '(33 reviews)',
#   'url': '/biz/ch%C3%A8res-cousines-lyon-8?osq=burger'},
#  {'name': 'King Tacos',
#   'location': '8ème arrondissement',
#   'rating': '5.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/king-tacos-lyon-2?osq=burger'},
#  {'name': 'Le Comptoir du Poulet',
#   'location': 'Terreaux',
#   'rating': '3.9 ',
#   'nb_reviews': '(14 reviews)',
#   'url': '/biz/le-comptoir-du-poulet-lyon-2?osq=burger'},
#  {'name': 'McDonald’s',
#   'location': 'Charpennes',
#   'rating': '2.4 ',
#   'nb_reviews': '(19 reviews)',
#   'url': '/biz/mcdonalds-villeurbanne-3?osq=burger'},
#  {'name': 'L’Essentiel',
#   'location': 'Garibaldi',
#   'rating': '3.4 ',
#   'nb_reviews': '(31 reviews)',
#   'url': '/biz/l-essentiel-lyon-2?osq=burger'},
#  {'name': '#nam',
#   'location': 'La Guillotière',
#   'rating': '4.3 ',
#   'nb_reviews': '(122 reviews)',
#   'url': '/biz/nam-lyon?osq=burger'},
#  {'name': 'Bar des Oliviers',
#   'location': 'Jean Macé',
#   'rating': '4.4 ',
#   'nb_reviews': '(12 reviews)',
#   'url': '/biz/bar-des-oliviers-lyon?osq=burger'},
#  {'name': 'Obamo Café',
#   'location': '3ème arrondissement',
#   'rating': '4.5 ',
#   'nb_reviews': '(48 reviews)',
#   'url': '/biz/obamo-caf%C3%A9-lyon-4?osq=burger'},
#  {'name': 'La Fabrique Givrée',
#   'location': 'Saint-Jean',
#   'rating': '3.9 ',
#   'nb_reviews': '(50 reviews)',
#   'url': '/biz/la-fabrique-givr%C3%A9e-lyon?osq=burger'},
#  {'name': 'Chez GG',
#   'location': 'Saint-Paul',
#   'rating': '3.4 ',
#   'nb_reviews': '(8 reviews)',
#   'url': '/biz/chez-gg-lyon?osq=burger'},
#  {'name': 'Ouest Express',
#   'location': '9ème arrondissement',
#   'rating': '3.5 ',
#   'nb_reviews': '(66 reviews)',
#   'url': '/biz/ouest-express-lyon-6?osq=burger'},
#  {'name': 'Le Comptoir de l’industrie',
#   'location': '9ème arrondissement',
#   'rating': '3.4 ',
#   'nb_reviews': '(7 reviews)',
#   'url': '/biz/le-comptoir-de-l-industrie-lyon?osq=burger'},
#  {'name': 'Au Jardin d’Anaïs',
#   'location': 'Monplaisir',
#   'rating': '3.8 ',
#   'nb_reviews': '(26 reviews)',
#   'url': '/biz/au-jardin-d-ana%C3%AFs-lyon-4?osq=burger'},
#  {'name': 'Burger & Wine',
#   'location': 'Confluence',
#   'rating': '3.2 ',
#   'nb_reviews': '(73 reviews)',
#   'url': '/biz/burger-et-wine-lyon-2?osq=burger'},
#  {'name': 'Cooker’s',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '3.1 ',
#   'nb_reviews': '(8 reviews)',
#   'url': '/biz/cookers-lyon-2?osq=burger'},
#  {'name': 'Candy Cookie',
#   'location': 'Terreaux',
#   'rating': '3.9 ',
#   'nb_reviews': '(72 reviews)',
#   'url': '/biz/candy-cookie-lyon?osq=burger'},
#  {'name': 'Mcdonald’s',
#   'location': 'La Guillotière',
#   'rating': '2.2 ',
#   'nb_reviews': '(20 reviews)',
#   'url': '/biz/mcdonalds-lyon-13?osq=burger'},
#  {'name': 'La Roulotte à Manu',
#   'location': '€€',
#   'rating': '5.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/la-roulotte-%C3%A0-manu-champagne-au-mont-d-or?osq=burger'},
#  {'name': 'Le Tacos Lyonnais',
#   'location': 'Garibaldi',
#   'rating': '1.8 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/le-tacos-lyonnais-lyon?osq=burger'},
#  {'name': 'Kaffee Berlin',
#   'location': 'Sans-Souci',
#   'rating': '3.8 ',
#   'nb_reviews': '(140 reviews)',
#   'url': '/biz/kaffee-berlin-lyon-3?osq=burger'},
#  {'name': 'Ouest Express',
#   'location': 'Confluence',
#   'rating': '3.7 ',
#   'nb_reviews': '(16 reviews)',
#   'url': '/biz/ouest-express-lyon-7?osq=burger'},
#  {'name': 'Kry’s Burgers',
#   'location': '€€',
#   'rating': '3.3 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/krys-burgers-limonest?osq=burger'},
#  {'name': 'Les Gratinés',
#   'location': '3ème arrondissement',
#   'rating': '3.5 ',
#   'nb_reviews': '(8 reviews)',
#   'url': '/biz/les-gratin%C3%A9s-lyon?osq=burger'},
#  {'name': 'Brasserie de l’Enregistrement',
#   'location': '3ème arrondissement',
#   'rating': '4.0 ',
#   'nb_reviews': '(7 reviews)',
#   'url': '/biz/brasserie-de-l-enregistrement-lyon?osq=burger'},
#  {'name': 'Le Burger des Garçons',
#   'location': 'Part-Dieu',
#   'rating': '3.7 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/le-burger-des-gar%C3%A7ons-lyon-2?osq=burger'},
#  {'name': 'Le Camion Toqué',
#   'location': '3ème arrondissement',
#   'rating': '2.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/le-camion-toqu%C3%A9-lyon?osq=burger'},
#  {'name': 'Le Sous-Marin Jaune',
#   'location': '2ème arrondissement',
#   'rating': '4.0 ',
#   'nb_reviews': '(7 reviews)',
#   'url': '/biz/le-sous-marin-jaune-lyon?osq=burger'},
#  {'name': 'Ma Cantine Gourmande',
#   'location': 'Lyon',
#   'rating': '3.8 ',
#   'nb_reviews': '(4 reviews)',
#   'url': '/biz/ma-cantine-gourmande-lyon-2?osq=burger'},
#  {'name': 'Le Café du Musée',
#   'location': 'Cité Internationale',
#   'rating': '1.7 ',
#   'nb_reviews': '(18 reviews)',
#   'url': '/biz/le-caf%C3%A9-du-mus%C3%A9e-lyon-2?osq=burger'},
#  {'name': 'Bistrot Jutard',
#   'location': 'Croix-Rousse',
#   'rating': '4.2 ',
#   'nb_reviews': '(26 reviews)',
#   'url': '/biz/bistrot-jutard-lyon?osq=burger'},
#  {'name': 'Dersim',
#   'location': 'Part-Dieu',
#   'rating': '5.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/dersim-lyon?osq=burger'},
#  {'name': 'Ninkasi Sans Souci',
#   'location': 'Sans-Souci',
#   'rating': '2.8 ',
#   'nb_reviews': '(55 reviews)',
#   'url': '/biz/ninkasi-sans-souci-lyon-08-2?osq=burger'},
#  {'name': 'Le Voxx',
#   'location': '1er arrondissement',
#   'rating': '3.4 ',
#   'nb_reviews': '(49 reviews)',
#   'url': '/biz/le-voxx-lyon?osq=burger'},
#  {'name': 'Le Comptoir 41',
#   'location': 'Vaise',
#   'rating': '3.5 ',
#   'nb_reviews': '(12 reviews)',
#   'url': '/biz/le-comptoir-41-lyon?osq=burger'},
#  {'name': 'Le Burger de Papa',
#   'location': 'Cordeliers',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/le-burger-de-papa-lyon?osq=burger'},
#  {'name': 'Ninkasi',
#   'location': 'Croix-Rousse',
#   'rating': '3.0 ',
#   'nb_reviews': '(40 reviews)',
#   'url': '/biz/ninkasi-lyon-13?osq=burger'},
#  {'name': 'L’Interlude',
#   'location': 'Terreaux',
#   'rating': '4.2 ',
#   'nb_reviews': '(30 reviews)',
#   'url': '/biz/l-interlude-lyon?osq=burger'},
#  {'name': 'Ultimate Burger',
#   'location': 'Grange Blanche',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/ultimate-burger-lyon?osq=burger'},
#  {'name': 'Marché des Quais du Rhône Victor Augagneur',
#   'location': 'Berges du Rhône',
#   'rating': '4.0 ',
#   'nb_reviews': '(19 reviews)',
#   'url': '/biz/march%C3%A9-des-quais-du-rh%C3%B4ne-victor-augagneur-lyon?osq=burger'},
#  {'name': 'Brasserie Gallay',
#   'location': 'Foch',
#   'rating': '4.0 ',
#   'nb_reviews': '(15 reviews)',
#   'url': '/biz/brasserie-gallay-lyon?osq=burger'},
#  {'name': 'Accasbel',
#   'location': 'Perrache',
#   'rating': '4.3 ',
#   'nb_reviews': '(7 reviews)',
#   'url': '/biz/accasbel-lyon?osq=burger'},
#  {'name': 'Meza',
#   'location': 'Jean Macé',
#   'rating': '4.3 ',
#   'nb_reviews': '(52 reviews)',
#   'url': '/biz/meza-lyon?osq=burger'},
#  {'name': 'The Burger Shop',
#   'location': 'Charpennes',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/the-burger-shop-villeurbanne?osq=burger'},
#  {'name': 'Bryan’s Café',
#   'location': 'Charpennes',
#   'rating': '3.5 ',
#   'nb_reviews': '(26 reviews)',
#   'url': '/biz/bryans-caf%C3%A9-villeurbanne-2?osq=burger'},
#  {'name': 'Le Baryton',
#   'location': 'Terreaux',
#   'rating': '3.7 ',
#   'nb_reviews': '(35 reviews)',
#   'url': '/biz/le-baryton-lyon?osq=burger'},
#  {'name': 'Speed Burger',
#   'location': '€',
#   'rating': '2.2 ',
#   'nb_reviews': '(9 reviews)',
#   'url': '/biz/speed-burger-villeurbanne?osq=burger'},
#  {'name': 'L’As du Burger',
#   'location': 'Gratte-Ciel',
#   'rating': '2.7 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/l-as-du-burger-villeurbanne?osq=burger'},
#  {'name': '160 Food',
#   'location': None,
#   'rating': '5.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/160-food-lyon?osq=burger'},
#  {'name': 'Chez d’Jo',
#   'location': 'Caluire',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/chez-d-jo-caluire-et-cuire?osq=burger'},
#  {'name': 'Ninkasi - Gorge De Loup',
#   'location': 'Vaise',
#   'rating': '2.8 ',
#   'nb_reviews': '(4 reviews)',
#   'url': '/biz/ninkasi-gorge-de-loup-lyon-2?osq=burger'},
#  {'name': 'Café 203',
#   'location': 'Terreaux',
#   'rating': '3.4 ',
#   'nb_reviews': '(153 reviews)',
#   'url': '/biz/caf%C3%A9-203-lyon-3?osq=burger'},
#  {'name': 'Popotte & Co',
#   'location': 'Vaise',
#   'rating': '4.6 ',
#   'nb_reviews': '(11 reviews)',
#   'url': '/biz/popotte-et-co-lyon?osq=burger'},
#  {'name': 'Hall Burger Lyon',
#   'location': 'Saxe-Gambetta',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/hall-burger-lyon-lyon?osq=burger'},
#  {'name': 'Amigo Pizza',
#   'location': '7ème arrondissement',
#   'rating': '2.0 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/amigo-pizza-lyon?osq=burger'},
#  {'name': 'Steak n Shake',
#   'location': 'Cordeliers',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/steak-n-shake-lyon-4?osq=burger'},
#  {'name': 'F&B City',
#   'location': 'Cité Internationale',
#   'rating': '3.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/f-et-b-city-lyon?osq=burger'},
#  {'name': 'CRAZY SALMON',
#   'location': 'Cordeliers',
#   'rating': '3.6 ',
#   'nb_reviews': '(211 reviews)',
#   'url': '/biz/crazy-salmon-lyon?osq=burger'},
#  {'name': 'Pique-Nique en Ville',
#   'location': 'Cordeliers',
#   'rating': '3.8 ',
#   'nb_reviews': '(22 reviews)',
#   'url': '/biz/pique-nique-en-ville-lyon-2?osq=burger'},
#  {'name': 'Bomp!',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '3.9 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/bomp-lyon?osq=burger'},
#  {'name': 'N’Café Confluence',
#   'location': 'Confluence',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/n-caf%C3%A9-confluence-lyon?osq=burger'},
#  {'name': 'All 54',
#   'location': 'Part-Dieu',
#   'rating': '2.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/all-54-lyon?osq=burger'},
#  {'name': 'Les Fils à Maman',
#   'location': 'Terreaux',
#   'rating': '3.7 ',
#   'nb_reviews': '(124 reviews)',
#   'url': '/biz/les-fils-%C3%A0-maman-lyon?osq=burger'},
#  {'name': 'Les Tuileries',
#   'location': '€€',
#   'rating': '4.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/les-tuileries-tassin-la-demi-lune?osq=burger'},
#  {'name': 'Autour d’un Verre',
#   'location': 'Cordeliers',
#   'rating': '3.8 ',
#   'nb_reviews': '(25 reviews)',
#   'url': '/biz/autour-d-un-verre-lyon-1er?osq=burger'},
#  {'name': 'L’Osteria de Lello',
#   'location': 'Part-Dieu',
#   'rating': '4.5 ',
#   'nb_reviews': '(94 reviews)',
#   'url': '/biz/l-osteria-de-lello-lyon?osq=burger'},
#  {'name': 'Burger King',
#   'location': 'Part-Dieu',
#   'rating': '2.8 ',
#   'nb_reviews': '(23 reviews)',
#   'url': '/biz/burger-king-lyon-5?osq=burger'},
#  {'name': 'Fafa Sushi',
#   'location': 'Bellecour',
#   'rating': '4.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/fafa-sushi-lyon?osq=burger'},
#  {'name': 'Pléthore et Balthazar',
#   'location': 'Bellecour',
#   'rating': '3.3 ',
#   'nb_reviews': '(47 reviews)',
#   'url': '/biz/pl%C3%A9thore-et-balthazar-lyon?osq=burger'},
#  {'name': 'Maître Boeuf',
#   'location': 'Saint-Jean',
#   'rating': '3.4 ',
#   'nb_reviews': '(50 reviews)',
#   'url': '/biz/ma%C3%AEtre-boeuf-lyon-4?osq=burger'},
#  {'name': 'Moda Food',
#   'location': 'Brotteaux',
#   'rating': '3.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/moda-food-lyon?osq=burger'},
#  {'name': 'L’industrie',
#   'location': 'Monplaisir',
#   'rating': '2.4 ',
#   'nb_reviews': '(30 reviews)',
#   'url': '/biz/l-industrie-lyon?osq=burger'},
#  {'name': 'Happy Times',
#   'location': 'Terreaux',
#   'rating': '2.9 ',
#   'nb_reviews': '(18 reviews)',
#   'url': '/biz/happy-times-lyon?osq=burger'},
#  {'name': 'Kry’s Burgers',
#   'location': None,
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/krys-burgers-tassin-la-demi-lune?osq=burger'},
#  {'name': 'Cigkoftem',
#   'location': 'Saxe-Gambetta',
#   'rating': '3.6 ',
#   'nb_reviews': '(13 reviews)',
#   'url': '/biz/cigkoftem-lyon-2?osq=burger'},
#  {'name': 'L’Entre-Temps',
#   'location': '€',
#   'rating': '4.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/l-entre-temps-saint-priest?osq=burger'},
#  {'name': 'Léon de B',
#   'location': 'Cordeliers',
#   'rating': '3.1 ',
#   'nb_reviews': '(49 reviews)',
#   'url': '/biz/l%C3%A9on-de-b-lyon-2?osq=burger'},
#  {'name': 'La Marinade',
#   'location': '€',
#   'rating': '3.0 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/la-marinade-villeurbanne?osq=burger'},
#  {'name': 'Ayers Rock Boat',
#   'location': 'Berges du Rhône',
#   'rating': '3.0 ',
#   'nb_reviews': '(51 reviews)',
#   'url': '/biz/ayers-rock-boat-lyon?osq=burger'},
#  {'name': 'Cowfish',
#   'location': None,
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/cowfish-dardilly?osq=burger'},
#  {'name': 'La Boite à Burger',
#   'location': 'Cordeliers',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/la-boite-%C3%A0-burger-lyon?osq=burger'},
#  {'name': 'La Cantina de Lello',
#   'location': 'Part-Dieu',
#   'rating': '4.4 ',
#   'nb_reviews': '(16 reviews)',
#   'url': '/biz/la-cantina-de-lello-lyon-3?osq=burger'},
#  {'name': 'Café Ampère',
#   'location': 'Ainay',
#   'rating': '3.0 ',
#   'nb_reviews': '(4 reviews)',
#   'url': '/biz/caf%C3%A9-amp%C3%A8re-lyon-2e-arrondissement?osq=burger'},
#  {'name': 'Burger store',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/burger-store-lyon-1er?osq=burger'},
#  {'name': 'Bistrot de la Passerelle',
#   'location': 'Bellecour',
#   'rating': '3.6 ',
#   'nb_reviews': '(35 reviews)',
#   'url': '/biz/bistrot-de-la-passerelle-lyon?osq=burger'},
#  {'name': '126 Food Avenue',
#   'location': 'Saxe-Gambetta',
#   'rating': '1.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/126-food-avenue-lyon?osq=burger'},
#  {'name': 'Yabio',
#   'location': 'Charpennes',
#   'rating': '1.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/yabio-lyon-3?osq=burger'},
#  {'name': 'Ninkasi Guillotière',
#   'location': 'La Guillotière',
#   'rating': '2.8 ',
#   'nb_reviews': '(55 reviews)',
#   'url': '/biz/ninkasi-guilloti%C3%A8re-lyon?osq=burger'},
#  {'name': 'McDonald’s',
#   'location': 'Ainay',
#   'rating': '3.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/mcdonalds-lyon-18?osq=burger'},
#  {'name': 'Bistro Zakka',
#   'location': 'La Guillotière',
#   'rating': '4.0 ',
#   'nb_reviews': '(74 reviews)',
#   'url': '/biz/bistro-zakka-lyon?osq=burger'},
#  {'name': 'Go Mex',
#   'location': 'Confluence',
#   'rating': '3.6 ',
#   'nb_reviews': '(50 reviews)',
#   'url': '/biz/go-mex-lyon?osq=burger'},
#  {'name': 'Au Pré Fleuri',
#   'location': 'Masséna',
#   'rating': '4.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/au-pr%C3%A9-fleuri-lyon?osq=burger'},
#  {'name': 'Maison Pozzoli',
#   'location': 'Gorge de Loup',
#   'rating': '3.4 ',
#   'nb_reviews': '(15 reviews)',
#   'url': '/biz/maison-pozzoli-lyon?osq=burger'},
#  {'name': 'Royal Burger',
#   'location': '7ème arrondissement',
#   'rating': '3.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/royal-burger-lyon?osq=burger'},
#  {'name': 'Midi Minuit',
#   'location': 'Confluence',
#   'rating': '3.5 ',
#   'nb_reviews': '(31 reviews)',
#   'url': '/biz/midi-minuit-lyon?osq=burger'},
#  {'name': 'Ninkasi Gerland',
#   'location': 'Gerland',
#   'rating': '3.5 ',
#   'nb_reviews': '(216 reviews)',
#   'url': '/biz/ninkasi-gerland-lyon-3?osq=burger'},
#  {'name': 'La Tablature',
#   'location': 'La Guillotière',
#   'rating': '3.6 ',
#   'nb_reviews': '(31 reviews)',
#   'url': '/biz/la-tablature-lyon?osq=burger'},
#  {'name': 'Les Enfants Terribles',
#   'location': 'Cordeliers',
#   'rating': '3.0 ',
#   'nb_reviews': '(60 reviews)',
#   'url': '/biz/les-enfants-terribles-lyon?osq=burger'},
#  {'name': 'Grand Café de la Préfecture',
#   'location': '3ème arrondissement',
#   'rating': '3.7 ',
#   'nb_reviews': '(39 reviews)',
#   'url': '/biz/grand-caf%C3%A9-de-la-pr%C3%A9fecture-lyon-3?osq=burger'},
#  {'name': 'Malting Pot',
#   'location': 'Sans-Souci',
#   'rating': '3.9 ',
#   'nb_reviews': '(26 reviews)',
#   'url': '/biz/malting-pot-lyon?osq=burger'},
#  {'name': 'Les Jardins de Saint Didier',
#   'location': None,
#   'rating': '3.3 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/les-jardins-de-saint-didier-saint-didier-au-mont-d-or?osq=burger'},
#  {'name': 'Le Briey',
#   'location': 'Saxe-Gambetta',
#   'rating': '4.9 ',
#   'nb_reviews': '(10 reviews)',
#   'url': '/biz/le-briey-lyon?osq=burger'},
#  {'name': 'Goramen',
#   'location': 'Cordeliers',
#   'rating': '3.4 ',
#   'nb_reviews': '(47 reviews)',
#   'url': '/biz/goramen-lyon?osq=burger'},
#  {'name': 'Le République',
#   'location': 'Bellecour',
#   'rating': '3.0 ',
#   'nb_reviews': '(86 reviews)',
#   'url': '/biz/le-r%C3%A9publique-lyon-4?osq=burger'},
#  {'name': 'McDonald’s',
#   'location': 'Sans-Souci',
#   'rating': '2.6 ',
#   'nb_reviews': '(15 reviews)',
#   'url': '/biz/mcdonalds-lyon-16?osq=burger'},
#  {'name': 'El Baraka',
#   'location': '2ème arrondissement',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/el-baraka-lyon-2?osq=burger'},
#  {'name': 'McDonald’s',
#   'location': 'Bellecour',
#   'rating': '1.5 ',
#   'nb_reviews': '(13 reviews)',
#   'url': '/biz/mcdonalds-lyon-10?osq=burger'},
#  {'name': 'Mc Donald’s',
#   'location': 'Cordeliers',
#   'rating': '2.2 ',
#   'nb_reviews': '(12 reviews)',
#   'url': '/biz/mc-donalds-lyon-11?osq=burger'},
#  {'name': 'La Paillote Fidésienne',
#   'location': '€',
#   'rating': '5.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/la-paillote-fid%C3%A9sienne-sainte-foy-l%C3%A8s-lyon-2?osq=burger'},
#  {'name': 'Les Bobos',
#   'location': 'Croix-Rousse',
#   'rating': '4.1 ',
#   'nb_reviews': '(45 reviews)',
#   'url': '/biz/les-bobos-lyon?osq=burger'},
#  {'name': 'Play Express',
#   'location': '€€',
#   'rating': '1.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/play-express-dardilly?osq=burger'},
#  {'name': 'Steak and Co',
#   'location': 'Charpennes',
#   'rating': '2.8 ',
#   'nb_reviews': '(13 reviews)',
#   'url': '/biz/steak-and-co-lyon?osq=burger'},
#  {'name': 'Brasserie Marius',
#   'location': 'Part-Dieu',
#   'rating': '3.4 ',
#   'nb_reviews': '(11 reviews)',
#   'url': '/biz/brasserie-marius-lyon?osq=burger'},
#  {'name': 'Croc & Go',
#   'location': '6ème arrondissement',
#   'rating': '2.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/croc-et-go-lyon?osq=burger'},
#  {'name': 'Etche Berry',
#   'location': 'Cordeliers',
#   'rating': '2.8 ',
#   'nb_reviews': '(8 reviews)',
#   'url': '/biz/etche-berry-lyon?osq=burger'},
#  {'name': 'King Tacos',
#   'location': 'Gratte-Ciel',
#   'rating': '4.7 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/king-tacos-villeurbanne?osq=burger'},
#  {'name': 'Le Blind Pig',
#   'location': 'Masséna',
#   'rating': '4.1 ',
#   'nb_reviews': '(32 reviews)',
#   'url': '/biz/le-blind-pig-lyon?osq=burger'},
#  {'name': 'La Buvette du Pont Wilson',
#   'location': 'Berges du Rhône',
#   'rating': '3.6 ',
#   'nb_reviews': '(14 reviews)',
#   'url': '/biz/la-buvette-du-pont-wilson-lyon?osq=burger'},
#  {'name': 'Le Mondrian',
#   'location': 'La Guillotière',
#   'rating': '3.3 ',
#   'nb_reviews': '(57 reviews)',
#   'url': '/biz/le-mondrian-lyon?osq=burger'},
#  {'name': 'Suelta Verde',
#   'location': 'Cité Internationale',
#   'rating': '2.4 ',
#   'nb_reviews': '(41 reviews)',
#   'url': '/biz/suelta-verde-lyon?osq=burger'},
#  {'name': 'Setifis',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '4.0 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/setifis-lyon?osq=burger'},
#  {'name': 'Speed Burger',
#   'location': 'La Guillotière',
#   'rating': '2.1 ',
#   'nb_reviews': '(11 reviews)',
#   'url': '/biz/speed-burger-lyon-3?osq=burger'},
#  {'name': 'The Rolling Cantine',
#   'location': '€€',
#   'rating': '3.7 ',
#   'nb_reviews': '(61 reviews)',
#   'url': '/biz/the-rolling-cantine-villeurbanne-6?osq=burger'},
#  {'name': 'Jardin du Pré Fleuri',
#   'location': '€€€',
#   'rating': '4.6 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/jardin-du-pr%C3%A9-fleuri-villeurbanne-2?osq=burger'},
#  {'name': 'Ninkasi La Soie',
#   'location': '€€',
#   'rating': '2.7 ',
#   'nb_reviews': '(6 reviews)',
#   'url': '/biz/ninkasi-la-soie-villeurbanne-3?osq=burger'},
#  {'name': 'Au Tooley’s',
#   'location': 'Saint-Georges',
#   'rating': '3.3 ',
#   'nb_reviews': '(12 reviews)',
#   'url': '/biz/au-tooleys-lyon?osq=burger'},
#  {'name': 'Tacos Street',
#   'location': None,
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/tacos-street-saint-priest?osq=burger'},
#  {'name': 'La Maie du 26',
#   'location': 'Jean Macé',
#   'rating': '4.2 ',
#   'nb_reviews': '(11 reviews)',
#   'url': '/biz/la-maie-du-26-lyon?osq=burger'},
#  {'name': 'Suzette and Co',
#   'location': 'Terreaux',
#   'rating': '2.9 ',
#   'nb_reviews': '(17 reviews)',
#   'url': '/biz/suzette-and-co-lyon?osq=burger'},
#  {'name': 'L’Unique',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': '4.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/l-unique-lyon?osq=burger'},
#  {'name': 'Ligne 102',
#   'location': '€',
#   'rating': '4.6 ',
#   'nb_reviews': '(8 reviews)',
#   'url': '/biz/ligne-102-ecully?osq=burger'},
#  {'name': 'Oxxo',
#   'location': None,
#   'rating': '4.5 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/oxxo-villeurbanne?osq=burger'},
#  {'name': 'Quick',
#   'location': 'Gratte-Ciel',
#   'rating': '1.3 ',
#   'nb_reviews': '(7 reviews)',
#   'url': '/biz/quick-villeurbanne-2?osq=burger'},
#  {'name': 'Le Dandy',
#   'location': 'Cordeliers',
#   'rating': '2.8 ',
#   'nb_reviews': '(6 reviews)',
#   'url': '/biz/le-dandy-lyon?osq=burger'},
#  {'name': 'Woko',
#   'location': 'Part-Dieu',
#   'rating': '3.4 ',
#   'nb_reviews': '(64 reviews)',
#   'url': '/biz/woko-lyon-7?osq=burger'},
#  {'name': 'McDonald’s',
#   'location': 'Cordeliers',
#   'rating': '2.8 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/mcdonalds-lyon-17?osq=burger'},
#  {'name': 'Pronto Burger',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/pronto-burger-lyon?osq=burger'},
#  {'name': 'Made in Fish',
#   'location': 'Ainay',
#   'rating': '3.6 ',
#   'nb_reviews': '(48 reviews)',
#   'url': '/biz/made-in-fish-lyon?osq=burger'},
#  {'name': 'Bar le Terminus',
#   'location': 'Saint-Just',
#   'rating': '3.3 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/bar-le-terminus-lyon-2?osq=burger'},
#  {'name': 'Tomē',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/tom%C4%93-lyon-2?osq=burger'},
#  {'name': 'Ninkasi Gratte-Ciel',
#   'location': 'Gratte-Ciel',
#   'rating': '3.2 ',
#   'nb_reviews': '(50 reviews)',
#   'url': '/biz/ninkasi-gratte-ciel-villeurbanne?osq=burger'},
#  {'name': 'McDonald’s',
#   'location': 'Gerland',
#   'rating': '2.2 ',
#   'nb_reviews': '(5 reviews)',
#   'url': '/biz/mcdonalds-lyon-11?osq=burger'},
#  {'name': 'Tip Top Burger',
#   'location': None,
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/tip-top-burger-villeurbanne?osq=burger'},
#  {'name': 'Woko',
#   'location': 'Confluence',
#   'rating': '3.0 ',
#   'nb_reviews': '(59 reviews)',
#   'url': '/biz/woko-lyon-8?osq=burger'},
#  {'name': 'Le Saxe',
#   'location': '3ème arrondissement',
#   'rating': '3.0 ',
#   'nb_reviews': '(2 reviews)',
#   'url': '/biz/le-saxe-lyon-3?osq=burger'},
#  {'name': 'Le Jardin de Berthe',
#   'location': 'Terreaux',
#   'rating': '2.4 ',
#   'nb_reviews': '(39 reviews)',
#   'url': '/biz/le-jardin-de-berthe-lyon-3?osq=burger'},
#  {'name': 'Chez Marion',
#   'location': 'La Guillotière',
#   'rating': '3.0 ',
#   'nb_reviews': '(6 reviews)',
#   'url': '/biz/chez-marion-lyon?osq=burger'},
#  {'name': 'Burger&Fajitas',
#   'location': 'Pentes de la Croix-Rousse',
#   'rating': ' ',
#   'nb_reviews': None,
#   'url': '/biz/burger-et-fajitas-lyon?osq=burger'},
#  {'name': 'Le PS Burger',
#   'location': 'Maison de la Danse',
#   'rating': None,
#   'nb_reviews': None,
#   'url': '/biz/le-ps-burger-lyon-2?osq=burger'},
#  {'name': 'Tracteur et Bigoudis',
#   'location': '€€',
#   'rating': '4.7 ',
#   'nb_reviews': '(12 reviews)',
#   'url': '/biz/tracteur-et-bigoudis-villeurbanne?osq=burger'},
#  {'name': 'Café Français',
#   'location': 'Bellecour',
#   'rating': '3.0 ',
#   'nb_reviews': '(41 reviews)',
#   'url': '/biz/caf%C3%A9-fran%C3%A7ais-lyon-3?osq=burger'},
#  {'name': 'Le Bistrot de la Botte',
#   'location': 'Vieux-Lyon',
#   'rating': '3.4 ',
#   'nb_reviews': '(50 reviews)',
#   'url': '/biz/le-bistrot-de-la-botte-lyon?osq=burger'},
#  {'name': 'Monplaisir Côté Cour',
#   'location': 'Monplaisir',
#   'rating': '3.3 ',
#   'nb_reviews': '(68 reviews)',
#   'url': '/biz/monplaisir-c%C3%B4t%C3%A9-cour-lyon-2?osq=burger'},
#  {'name': 'Bk Food',
#   'location': 'Garibaldi',
#   'rating': '1.0 ',
#   'nb_reviews': '(1 review)',
#   'url': '/biz/bk-food-lyon?osq=burger'},
#  {'name': 'L’Auberge du Village',
#   'location': '€€€',
#   'rating': '3.7 ',
#   'nb_reviews': '(3 reviews)',
#   'url': '/biz/l-auberge-du-village-dardilly?osq=burger'}]

# %%
url_list = []
for restaurant in json_result:
    url = restaurant['url']
    url_list.append(url)

url_list
# Out:
# ['/biz/big-fernand-lyon?osq=burger',
#  '/biz/b%C3%ABnnie-organic-lyon?osq=burger',
#  '/biz/les-frangins-lyon?osq=burger',
#  '/biz/steak-n-shake-lyon-3?osq=burger',
#  '/biz/les-tontons-burgers-lyon?osq=burger',
#  '/biz/the-dogs-bollocks-lyon?osq=burger',
#  '/biz/cosy-corner-lyon?osq=burger',
#  '/biz/guy-et-sons-cordeliers-lyon?osq=burger',
#  '/biz/king-marcel-lyon-7?osq=burger',
#  '/biz/franklins-steakhouse-lyon?osq=burger',
#  '/biz/butcher-lyon?osq=burger',
#  '/biz/the-star-ferry-lyon?osq=burger',
#  '/biz/johnnys-kitchen-lyon?osq=burger',
#  '/biz/les-burgers-de-papa-lyon-8?osq=burger',
#  '/biz/kemptown-food-truck-lyon?osq=burger',
#  '/biz/le-zinc-%C3%A0-burger-lyon?osq=burger',
#  '/biz/the-new-world-smoke-lyon?osq=burger',
#  '/biz/les-burgers-de-papa-villeurbanne?osq=burger',
#  '/biz/burgers-et-bagels-lafayette-lyon?osq=burger',
#  '/biz/les-burgers-de-papa-lyon-5?osq=burger',
#  '/biz/bintje-et-zoet-lyon?osq=burger',
#  '/biz/balzamik-caluire-et-cuire?osq=burger',
#  '/biz/chicken-inn-lyon?osq=burger',
#  '/biz/afrika-burger-lyon?osq=burger',
#  '/biz/hank-burger-lyon-op%C3%A9ra-lyon?osq=burger',
#  '/biz/pinch-burger-lyon-2?osq=burger',
#  '/biz/burgers-saint-priest?osq=burger',
#  '/biz/yabio-lyon?osq=burger',
#  '/biz/les-burgers-de-papa-lyon-3?osq=burger',
#  '/biz/steak-n-shake-lyon-2?osq=burger',
#  '/biz/la-broche-lyon?osq=burger',
#  '/biz/king-marcel-lyon-9?osq=burger',
#  '/biz/mike-lyon?osq=burger',
#  '/biz/kaffee-berlin-lyon-4?osq=burger',
#  '/biz/la-fourmili%C3%A8re-lyon?osq=burger',
#  '/biz/lyons-gastropub-lyon?osq=burger',
#  '/biz/flanigans-lyon?osq=burger',
#  '/biz/big-fernand-lyon-3?osq=burger',
#  '/biz/la-kolok-lyon?osq=burger',
#  '/biz/les-burgers-de-papa-lyon-6?osq=burger',
#  '/biz/le-d%C3%A9licieux-caluire-et-cuire?osq=burger',
#  '/biz/yabio-lyon-2?osq=burger',
#  '/biz/l-origo-lyon?osq=burger',
#  '/biz/greg-et-jerrys-lyon?osq=burger',
#  '/biz/frite-alors-lyon-2?osq=burger',
#  '/biz/dorodi-pastry-lyon?osq=burger',
#  '/biz/frite-alors-lyon-3?osq=burger',
#  '/biz/guy-et-sons-charpennes-lyon?osq=burger',
#  '/biz/hard-rock-cafe-lyon-3?osq=burger',
#  '/biz/street-art-lyon-3?osq=burger',
#  '/biz/chez-gusto-lyon?osq=burger',
#  '/biz/d%C3%A9lice-croq-lyon-2?osq=burger',
#  '/biz/ninkasi-lyon-12?osq=burger',
#  '/biz/livestation-diy-lyon?osq=burger',
#  '/biz/the-wallace-lyon?osq=burger',
#  '/biz/diploid-lyon-2?osq=burger',
#  '/biz/eden-rock-caf%C3%A9-lyon-2?osq=burger',
#  '/biz/l-%C3%A9picerie-lyon-7?osq=burger',
#  '/biz/boston-tavern-lyon?osq=burger',
#  '/biz/la-grillardi%C3%A8re-lyon-2?osq=burger',
#  '/biz/queens-town-lyon?osq=burger',
#  '/biz/the-kellys-irish-pub-lyon-2?osq=burger',
#  '/biz/rems-lyon?osq=burger',
#  '/biz/steak-house-villeurbanne?osq=burger',
#  '/biz/akl%C3%A9-le-food-truck-lyon?osq=burger',
#  '/biz/le-bistrot-des-maquignons-lyon?osq=burger',
#  '/biz/burger-house-villeurbanne?osq=burger',
#  '/biz/le-caf%C3%A9-76-lyon-2?osq=burger',
#  '/biz/bistrot-du-boulevard-lyon?osq=burger',
#  '/biz/brooklyn-burgers-lyon?osq=burger',
#  '/biz/le-bistrot-canaille-lyon?osq=burger',
#  '/biz/le-van-%C3%A0-burgers-lyon-2?osq=burger',
#  '/biz/les-fromagivores-lyon?osq=burger',
#  '/biz/king-marcel-lyon-8?osq=burger',
#  '/biz/le-court-circuit-lyon?osq=burger',
#  '/biz/spok-lyon?osq=burger',
#  '/biz/mastertacos-lyon-2?osq=burger',
#  '/biz/la-mouss-tache-lyon?osq=burger',
#  '/biz/le-boulanger-de-saint-just-lyon?osq=burger',
#  '/biz/streat-food-lyon?osq=burger',
#  '/biz/hammamet-villeurbanne?osq=burger',
#  '/biz/eds-eat-et-drinks-lyon?osq=burger',
#  '/biz/beefhouse-lyon?osq=burger',
#  '/biz/sun-7-burger-lyon?osq=burger',
#  '/biz/les-terrasses-d-alex-villeurbanne?osq=burger',
#  '/biz/my-petite-factory-lyon?osq=burger',
#  '/biz/ch%C3%A8res-cousines-lyon-8?osq=burger',
#  '/biz/king-tacos-lyon-2?osq=burger',
#  '/biz/le-comptoir-du-poulet-lyon-2?osq=burger',
#  '/biz/mcdonalds-villeurbanne-3?osq=burger',
#  '/biz/l-essentiel-lyon-2?osq=burger',
#  '/biz/nam-lyon?osq=burger',
#  '/biz/bar-des-oliviers-lyon?osq=burger',
#  '/biz/obamo-caf%C3%A9-lyon-4?osq=burger',
#  '/biz/la-fabrique-givr%C3%A9e-lyon?osq=burger',
#  '/biz/chez-gg-lyon?osq=burger',
#  '/biz/ouest-express-lyon-6?osq=burger',
#  '/biz/le-comptoir-de-l-industrie-lyon?osq=burger',
#  '/biz/au-jardin-d-ana%C3%AFs-lyon-4?osq=burger',
#  '/biz/burger-et-wine-lyon-2?osq=burger',
#  '/biz/cookers-lyon-2?osq=burger',
#  '/biz/candy-cookie-lyon?osq=burger',
#  '/biz/mcdonalds-lyon-13?osq=burger',
#  '/biz/la-roulotte-%C3%A0-manu-champagne-au-mont-d-or?osq=burger',
#  '/biz/le-tacos-lyonnais-lyon?osq=burger',
#  '/biz/kaffee-berlin-lyon-3?osq=burger',
#  '/biz/ouest-express-lyon-7?osq=burger',
#  '/biz/krys-burgers-limonest?osq=burger',
#  '/biz/les-gratin%C3%A9s-lyon?osq=burger',
#  '/biz/brasserie-de-l-enregistrement-lyon?osq=burger',
#  '/biz/le-burger-des-gar%C3%A7ons-lyon-2?osq=burger',
#  '/biz/le-camion-toqu%C3%A9-lyon?osq=burger',
#  '/biz/le-sous-marin-jaune-lyon?osq=burger',
#  '/biz/ma-cantine-gourmande-lyon-2?osq=burger',
#  '/biz/le-caf%C3%A9-du-mus%C3%A9e-lyon-2?osq=burger',
#  '/biz/bistrot-jutard-lyon?osq=burger',
#  '/biz/dersim-lyon?osq=burger',
#  '/biz/ninkasi-sans-souci-lyon-08-2?osq=burger',
#  '/biz/le-voxx-lyon?osq=burger',
#  '/biz/le-comptoir-41-lyon?osq=burger',
#  '/biz/le-burger-de-papa-lyon?osq=burger',
#  '/biz/ninkasi-lyon-13?osq=burger',
#  '/biz/l-interlude-lyon?osq=burger',
#  '/biz/ultimate-burger-lyon?osq=burger',
#  '/biz/march%C3%A9-des-quais-du-rh%C3%B4ne-victor-augagneur-lyon?osq=burger',
#  '/biz/brasserie-gallay-lyon?osq=burger',
#  '/biz/accasbel-lyon?osq=burger',
#  '/biz/meza-lyon?osq=burger',
#  '/biz/the-burger-shop-villeurbanne?osq=burger',
#  '/biz/bryans-caf%C3%A9-villeurbanne-2?osq=burger',
#  '/biz/le-baryton-lyon?osq=burger',
#  '/biz/speed-burger-villeurbanne?osq=burger',
#  '/biz/l-as-du-burger-villeurbanne?osq=burger',
#  '/biz/160-food-lyon?osq=burger',
#  '/biz/chez-d-jo-caluire-et-cuire?osq=burger',
#  '/biz/ninkasi-gorge-de-loup-lyon-2?osq=burger',
#  '/biz/caf%C3%A9-203-lyon-3?osq=burger',
#  '/biz/popotte-et-co-lyon?osq=burger',
#  '/biz/hall-burger-lyon-lyon?osq=burger',
#  '/biz/amigo-pizza-lyon?osq=burger',
#  '/biz/steak-n-shake-lyon-4?osq=burger',
#  '/biz/f-et-b-city-lyon?osq=burger',
#  '/biz/crazy-salmon-lyon?osq=burger',
#  '/biz/pique-nique-en-ville-lyon-2?osq=burger',
#  '/biz/bomp-lyon?osq=burger',
#  '/biz/n-caf%C3%A9-confluence-lyon?osq=burger',
#  '/biz/all-54-lyon?osq=burger',
#  '/biz/les-fils-%C3%A0-maman-lyon?osq=burger',
#  '/biz/les-tuileries-tassin-la-demi-lune?osq=burger',
#  '/biz/autour-d-un-verre-lyon-1er?osq=burger',
#  '/biz/l-osteria-de-lello-lyon?osq=burger',
#  '/biz/burger-king-lyon-5?osq=burger',
#  '/biz/fafa-sushi-lyon?osq=burger',
#  '/biz/pl%C3%A9thore-et-balthazar-lyon?osq=burger',
#  '/biz/ma%C3%AEtre-boeuf-lyon-4?osq=burger',
#  '/biz/moda-food-lyon?osq=burger',
#  '/biz/l-industrie-lyon?osq=burger',
#  '/biz/happy-times-lyon?osq=burger',
#  '/biz/krys-burgers-tassin-la-demi-lune?osq=burger',
#  '/biz/cigkoftem-lyon-2?osq=burger',
#  '/biz/l-entre-temps-saint-priest?osq=burger',
#  '/biz/l%C3%A9on-de-b-lyon-2?osq=burger',
#  '/biz/la-marinade-villeurbanne?osq=burger',
#  '/biz/ayers-rock-boat-lyon?osq=burger',
#  '/biz/cowfish-dardilly?osq=burger',
#  '/biz/la-boite-%C3%A0-burger-lyon?osq=burger',
#  '/biz/la-cantina-de-lello-lyon-3?osq=burger',
#  '/biz/caf%C3%A9-amp%C3%A8re-lyon-2e-arrondissement?osq=burger',
#  '/biz/burger-store-lyon-1er?osq=burger',
#  '/biz/bistrot-de-la-passerelle-lyon?osq=burger',
#  '/biz/126-food-avenue-lyon?osq=burger',
#  '/biz/yabio-lyon-3?osq=burger',
#  '/biz/ninkasi-guilloti%C3%A8re-lyon?osq=burger',
#  '/biz/mcdonalds-lyon-18?osq=burger',
#  '/biz/bistro-zakka-lyon?osq=burger',
#  '/biz/go-mex-lyon?osq=burger',
#  '/biz/au-pr%C3%A9-fleuri-lyon?osq=burger',
#  '/biz/maison-pozzoli-lyon?osq=burger',
#  '/biz/royal-burger-lyon?osq=burger',
#  '/biz/midi-minuit-lyon?osq=burger',
#  '/biz/ninkasi-gerland-lyon-3?osq=burger',
#  '/biz/la-tablature-lyon?osq=burger',
#  '/biz/les-enfants-terribles-lyon?osq=burger',
#  '/biz/grand-caf%C3%A9-de-la-pr%C3%A9fecture-lyon-3?osq=burger',
#  '/biz/malting-pot-lyon?osq=burger',
#  '/biz/les-jardins-de-saint-didier-saint-didier-au-mont-d-or?osq=burger',
#  '/biz/le-briey-lyon?osq=burger',
#  '/biz/goramen-lyon?osq=burger',
#  '/biz/le-r%C3%A9publique-lyon-4?osq=burger',
#  '/biz/mcdonalds-lyon-16?osq=burger',
#  '/biz/el-baraka-lyon-2?osq=burger',
#  '/biz/mcdonalds-lyon-10?osq=burger',
#  '/biz/mc-donalds-lyon-11?osq=burger',
#  '/biz/la-paillote-fid%C3%A9sienne-sainte-foy-l%C3%A8s-lyon-2?osq=burger',
#  '/biz/les-bobos-lyon?osq=burger',
#  '/biz/play-express-dardilly?osq=burger',
#  '/biz/steak-and-co-lyon?osq=burger',
#  '/biz/brasserie-marius-lyon?osq=burger',
#  '/biz/croc-et-go-lyon?osq=burger',
#  '/biz/etche-berry-lyon?osq=burger',
#  '/biz/king-tacos-villeurbanne?osq=burger',
#  '/biz/le-blind-pig-lyon?osq=burger',
#  '/biz/la-buvette-du-pont-wilson-lyon?osq=burger',
#  '/biz/le-mondrian-lyon?osq=burger',
#  '/biz/suelta-verde-lyon?osq=burger',
#  '/biz/setifis-lyon?osq=burger',
#  '/biz/speed-burger-lyon-3?osq=burger',
#  '/biz/the-rolling-cantine-villeurbanne-6?osq=burger',
#  '/biz/jardin-du-pr%C3%A9-fleuri-villeurbanne-2?osq=burger',
#  '/biz/ninkasi-la-soie-villeurbanne-3?osq=burger',
#  '/biz/au-tooleys-lyon?osq=burger',
#  '/biz/tacos-street-saint-priest?osq=burger',
#  '/biz/la-maie-du-26-lyon?osq=burger',
#  '/biz/suzette-and-co-lyon?osq=burger',
#  '/biz/l-unique-lyon?osq=burger',
#  '/biz/ligne-102-ecully?osq=burger',
#  '/biz/oxxo-villeurbanne?osq=burger',
#  '/biz/quick-villeurbanne-2?osq=burger',
#  '/biz/le-dandy-lyon?osq=burger',
#  '/biz/woko-lyon-7?osq=burger',
#  '/biz/mcdonalds-lyon-17?osq=burger',
#  '/biz/pronto-burger-lyon?osq=burger',
#  '/biz/made-in-fish-lyon?osq=burger',
#  '/biz/bar-le-terminus-lyon-2?osq=burger',
#  '/biz/tom%C4%93-lyon-2?osq=burger',
#  '/biz/ninkasi-gratte-ciel-villeurbanne?osq=burger',
#  '/biz/mcdonalds-lyon-11?osq=burger',
#  '/biz/tip-top-burger-villeurbanne?osq=burger',
#  '/biz/woko-lyon-8?osq=burger',
#  '/biz/le-saxe-lyon-3?osq=burger',
#  '/biz/le-jardin-de-berthe-lyon-3?osq=burger',
#  '/biz/chez-marion-lyon?osq=burger',
#  '/biz/burger-et-fajitas-lyon?osq=burger',
#  '/biz/le-ps-burger-lyon-2?osq=burger',
#  '/biz/tracteur-et-bigoudis-villeurbanne?osq=burger',
#  '/biz/caf%C3%A9-fran%C3%A7ais-lyon-3?osq=burger',
#  '/biz/le-bistrot-de-la-botte-lyon?osq=burger',
#  '/biz/monplaisir-c%C3%B4t%C3%A9-cour-lyon-2?osq=burger',
#  '/biz/bk-food-lyon?osq=burger',
#  '/biz/l-auberge-du-village-dardilly?osq=burger']

# %%
# Out:
# ['https://www.yelp.fr//biz/sanukiya-paris?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/sushi-yaki-paris-4?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/onigiriya-paris?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/aki-paris-2?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/okuda-paris?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/y-izakaya-paris?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/ippudo-paris-2?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/la-maison-du-sak%C3%A9-paris?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/teppanyaki-ginza-onodera-paris?osq=restaurant+japonais',
#  'https://www.yelp.fr//biz/ginza-paris-5?osq=restaurant+japonais']

# %% [markdown]
# 5. Scrape the list of urls and gather the following data about each restaurant (or place):
#     * name
#     * stars
#     * number of votes
#     * address
#     * opening hours
#     * phone
#     * amenities
#     * reviews

# %%
# !python 02-Optional_Scraping_Yelp/yelp4.py
# Out:
# 2022-03-18 17:39:16 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-03-18 17:39:16 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.2.0, Python 3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) - [GCC 9.4.0], pyOpenSSL 22.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 36.0.1, Platform Linux-5.4.144+-x86_64-with-glibc2.31
# 2022-03-18 17:39:16 [scrapy.crawler] INFO: Overridden settings:
# {'AUTOTHROTTLE_ENABLED': True, 'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2022-03-18 17:39:16 [scrapy.extensions.telnet] INFO: Telnet Password: e155f1a4f63028fc
# 2022-03-18 17:39:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2022-03-18 17:39:16 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-03-18 17:39:16 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-03-18 17:39:16 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-03-18 17:39:16 [scrapy.core.engine] INFO: Spider opened
# 2022-03-18 17:39:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-03-18 17:39:17 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-03-18 17:40:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-03-18 17:41:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-03-18 17:42:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-03-18 17:42:29 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.yelp.fr//biz/sanukiya-paris?osq=restaurant+japonais> (failed 3 times): 503 Service Unavailable
# 2022-03-18 17:42:29 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <503 https://www.yelp.fr//biz/sanukiya-paris?osq=restaurant+japonais>: HTTP status code is not handled or not allowed
# 2022-03-18 17:42:36 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.yelp.fr//biz/sushi-yaki-paris-4?osq=restaurant+japonais> (failed 3 times): 503 Service Unavailable
# 2022-03-18 17:42:37 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <503 https://www.yelp.fr//biz/sushi-yaki-paris-4?osq=restaurant+japonais>: HTTP status code is not handled or not allowed
# 2022-03-18 17:42:44 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.yelp.fr//biz/onigiriya-paris?osq=restaurant+japonais> (failed 3 times): 503 Service Unavailable
# 2022-03-18 17:42:44 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <503 https://www.yelp.fr//biz/onigiriya-paris?osq=restaurant+japonais>: HTTP status code is not handled or not allowed
# 2022-03-18 17:42:50 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.yelp.fr//biz/aki-paris-2?osq=restaurant+japonais> (failed 3 times): 503 Service Unavailable
# 2022-03-18 17:42:50 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <503 https://www.yelp.fr//biz/aki-paris-2?osq=restaurant+japonais>: HTTP status code is not handled or not allowed
# ^C
# 2022-03-18 17:42:55 [scrapy.crawler] INFO: Received SIGINT, shutting down gracefully. Send again to force
# 2022-03-18 17:42:55 [scrapy.core.engine] INFO: Closing spider (shutdown)
